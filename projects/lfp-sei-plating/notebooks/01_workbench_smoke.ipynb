# %% [markdown]
# # LFP 仿真工作台：可复现入口
#
# 这个 Notebook 只调用 `lfp_lab` 的核心运行入口，不复制模型构建或求解逻辑。默认执行缩短版数值烟雾测试；正式结果请在命令行运行不带 `--quick` 的案例。

# %%
from IPython.display import Image, display

from lfp_lab.run import run_case

# %%
result = run_case("baseline", quick=True)
result.manifest["run_status"], result.output_dir

# %%
result.summary

# %%
display(Image(filename=str(result.output_dir / "overview.png")))
